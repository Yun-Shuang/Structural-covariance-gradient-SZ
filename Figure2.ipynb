# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# plot hist for gradients of two groups
df2 = pd.read_csv(r'/media/shuang/data/Covariance/results/hist.csv')
ax=sns.displot(data=df2, x="G1", hue="group2",palette={2:'#4d4d4d', 1:'#33a02c'},alpha=0.5)
ax.set(xlim=(-0.04, 0.07))
plt.savefig("/media/shuang/data/Covariance/Hist.svg", format="svg",dpi=1000)

# %%
sns.set_theme(style="whitegrid")
# Plot the distribution of functional networks of HC gradient
sns.displot(
    data=df,
    x="HCG1", hue="yeo",
    kind="kde", height=6,
    multiple="fill", clip=(-0.0385, 0.0672),
    palette={1:'#781285', 2:'#4682B4', 3:'#00760E', 4:'#C439F8', 5:'#dcf8a3', 6:'#E69220', 7:'#CD3C4E'},
)
plt.savefig("/media/shuang/data/Covariance/HCn7.svg", format="svg",dpi=1000)

# %%
sns.set_theme(style="whitegrid")
# Plot the distribution of functional networks of EOS gradient
sns.displot(
    data=df,
    x="EOSG1", hue="yeo",
    kind="kde", height=6,
    multiple="fill", clip=(-0.0327, 0.0496),
    palette={1:'#781285', 2:'#4682B4', 3:'#00760E', 4:'#C439F8', 5:'#dcf8a3', 6:'#E69220', 7:'#CD3C4E'},
)
plt.savefig("/media/shuang/data/Covariance/EOSn7.svg", format="svg",dpi=1000)

# %%
sns.set_theme(style="whitegrid")
# Plot the distribution of cytoarchitectural networks of HC gradient
sns.displot(
    data=df,
    x="HCG1", hue="eco",
    kind="kde", height=6,
    multiple="fill", clip=(-0.0385, 0.0672),
    palette={0:'#FFFFFF',1:'#7c287b', 2:'#305c87', 3:'#a0c886', 4:'#bb9c10', 5:'#e1da19'})
plt.savefig("/media/shuang/data/Covariance/HCeco5.svg", format="svg",dpi=1000)

# %%
sns.set_theme(style="whitegrid")
# Plot the distribution of cytoarchitectural networks of EOS gradient
sns.displot(
    data=df,
    x="EOSG1", hue="eco",
    kind="kde", height=6,
    multiple="fill", clip=(-0.0327, 0.0496),
    palette={0:'#FFFFFF',1:'#7c287b', 2:'#305c87', 3:'#a0c886', 4:'#bb9c10', 5:'#e1da19'})
plt.savefig("/media/shuang/data/Covariance/EOSeco5.svg", format="svg",dpi=1000)

# %%
# plot radar of functional networks of gradients
import plotly.graph_objects as go
categories = ['VIS', 'SMN', 'DAN', 'VAN', 'LMB', 'FPN', 'DMN']
fig = go.Figure()
fig.add_trace(go.Scatterpolar(
      r=[-0.0174342376185578,
-0.00733290357390114,
-0.00335553498463777,
0.00621597759607811,
0.0105836131795144,
0.0104967033047134,
0.00733621557492980],
      theta=categories,
      fill='toself',
      name='HC'
))
fig.add_trace(go.Scatterpolar(
      r=[-0.0156817721377945,
-0.00369076457278049,
-0.00335270316733032,
0.00497447554122626,
0.000988946717760862,
0.00919178643070589,
0.00725065565094976],
      theta=categories,
      fill='toself',
      name='EOS'
))
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[-0.02, 0.02]
    )),
  showlegend=True
)
fig.write_image("/media/shuang/data/Covariance/yeo7.svg")
fig.show()
# Out:
# <div>                            <div id="d85bffac-b970-4fb1-84be-73998e7040a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d85bffac-b970-4fb1-84be-73998e7040a8")) {                    Plotly.newPlot(                        "d85bffac-b970-4fb1-84be-73998e7040a8",                        [{"fill":"toself","name":"HC","r":[-0.0174342376185578,-0.00733290357390114,-0.00335553498463777,0.00621597759607811,0.0105836131795144,0.0104967033047134,0.0073362155749298],"theta":["VIS","SMN","DAN","VAN","LMB","FPN","DMN"],"type":"scatterpolar"},{"fill":"toself","name":"EOS","r":[-0.0156817721377945,-0.00369076457278049,-0.00335270316733032,0.00497447554122626,0.000988946717760862,0.00919178643070589,0.00725065565094976],"theta":["VIS","SMN","DAN","VAN","LMB",
# ...

# %%
# plot radar of cytoarchitectural networks of gradients
categories = ['Agranular', 'Frontal', 'Parietal', 'Polar', 'Granular']
fig = go.Figure()
fig.add_trace(go.Scatterpolar(
      r=[0.00966937870011330,
0.000639141984754008,
-0.0114447484990094,
0.0267978558886536,
-0.0173869183116234],
      theta=categories,
      fill='toself',
      name='HC'
))
fig.add_trace(go.Scatterpolar(
      r=[0.0113250754336111,
0.000278284755887999,
-0.00976053984114518,
0.0123396370252907,
-0.0102502302355974],
      theta=categories,
      fill='toself',
      name='EOS'
))
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[-0.03, 0.03]
    )),
  showlegend=True
)
fig.write_image("/media/shuang/data/Covariance/eco5.svg")
fig.show()
# Out:
# <div>                            <div id="0f544035-512e-4a54-a934-c707fe79a41a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f544035-512e-4a54-a934-c707fe79a41a")) {                    Plotly.newPlot(                        "0f544035-512e-4a54-a934-c707fe79a41a",                        [{"fill":"toself","name":"HC","r":[0.0096693787001133,0.000639141984754008,-0.0114447484990094,0.0267978558886536,-0.0173869183116234],"theta":["Agranular","Frontal","Parietal","Polar","Granular"],"type":"scatterpolar"},{"fill":"toself","name":"EOS","r":[0.0113250754336111,0.000278284755887999,-0.00976053984114518,0.0123396370252907,-0.0102502302355974],"theta":["Agranular","Frontal","Parietal","Polar","Granular"],"type":"scatterpolar"}],                        {"
# ...
